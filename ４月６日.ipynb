# %%
# %%writefile test.txt
# Hello world!
# Out:
# Writing test.txt

# %%
with open('test.txt', 'r') as f:
    print(f.read())
# Out:
# Hello world!

# %%
# 書き込む文字列
str = """It is meaningless only to think my long further aims idly.
It is important to set my aims but at the same time I should confirm my present condition.
Unless I set the standard where I am in any level, I'll be puzzled about what I should do from now on."""
 
f = open('test.txt', 'w') # 書き込みモードで開く
f.write(str) # 引数の文字列をファイルに書き込む
f.close() # ファイルを閉じる

# %%
with open('test.txt', 'r') as f:
    print(f.read())
# Out:
# It is meaningless only to think my long further aims idly.
# It is important to set my aims but at the same time I should confirm my present condition.
# Unless I set the standard where I am in any level, I'll be puzzled about what I should do from now on.

# %%
import numpy as np

# %%
np.random.rand()
# Out:
# 0.41451696933030935

# %%
np.random.rand(5)
# Out:
# array([ 0.92393879,  0.85856994,  0.92503913,  0.22951214,  0.50070717])

# %%
np.random.rand(5, 5)
# Out:
# array([[ 0.50622526,  0.49830086,  0.61915541,  0.25220834,  0.74160227],
#        [ 0.53085627,  0.57814999,  0.76695385,  0.90051757,  0.25107003],
#        [ 0.34197571,  0.78236639,  0.4728218 ,  0.12692847,  0.08035198],
#        [ 0.27849991,  0.66663428,  0.36859851,  0.17008721,  0.39220967],
#        [ 0.19370563,  0.34499168,  0.29253878,  0.28935628,  0.54152525]])

# %%
np.random.rand(4, 3) * 40 + 30
# Out:
# array([[ 40.28444952,  32.9616564 ,  36.16951743],
#        [ 36.48223644,  37.88968873,  66.96172087],
#        [ 38.32191651,  69.81319432,  45.24504634],
#        [ 34.93457367,  35.69361308,  62.52452623]])

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

n_bins = 20
x0 = np.random.rand(100) 
x1 = np.random.rand(10000)
x2 = np.random.rand(1000000)
x3 = np.random.randn(100) 
x4 = np.random.randn(10000)
x5 = np.random.randn(1000000)
x6 = [np.random.normal(50,10) for n in range(100)]
x7 = [np.random.normal(50,10) for n in range(10000)]
x8 = [np.random.normal(50,10) for n in range(1000000)]

fig, axes = plt.subplots(nrows=3, ncols=3)
ax0, ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8 = axes.flat

ax0.hist(x0, n_bins, histtype='bar', label=labels)
ax0.set_title('rand(100)')

ax1.hist(x1, n_bins, histtype='bar', label=labels)
ax1.set_title('rand(10000)')

ax2.hist(x2, n_bins, histtype='bar', label=labels)
ax2.set_title('rand(1000000)')

ax3.hist(x3, n_bins, histtype='bar', label=labels)
ax3.set_title('randn(100)')

ax4.hist(x4, n_bins, histtype='bar', label=labels)
ax4.set_title('randn(10000)')

ax5.hist(x5, n_bins, histtype='bar', label=labels)
ax5.set_title('randn(1000000)')

ax6.hist(x6, n_bins, histtype='bar', label=labels)
ax6.set_title('normal(50,10 x100')

ax7.hist(x7, n_bins, histtype='bar', label=labels)
ax7.set_title('normal(50,10)x10000')

ax8.hist(x8, n_bins, histtype='bar', label=labels)
ax8.set_title('normal(50,10)x1000000')

plt.tight_layout()
plt.show()

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import NullFormatter

# the random data
x = np.random.randn(500)
y = (np.random.randn(500) ** 3 - x ** 3) / 10.

nullfmt = NullFormatter()         # no labels

# definitions for the axes
left, width = 0.1, 0.65
bottom, height = 0.1, 0.65
bottom_h = left_h = left + width + 0.02

rect_scatter = [left, bottom, width, height]
rect_histx = [left, bottom_h, width, 0.2]
rect_histy = [left_h, bottom, 0.2, height]

# start with a rectangular Figure
plt.figure(1, figsize=(8, 8))

axScatter = plt.axes(rect_scatter)
axHistx = plt.axes(rect_histx)
axHisty = plt.axes(rect_histy)

# no labels
axHistx.xaxis.set_major_formatter(nullfmt)
axHisty.yaxis.set_major_formatter(nullfmt)

# the scatter plot:
axScatter.scatter(x, y)

# now determine nice limits by hand:
binwidth = 0.25
xymax = np.max([np.max(np.fabs(x)), np.max(np.fabs(y))])
lim = (int(xymax/binwidth) + 1) * binwidth

axScatter.set_xlim((-lim, lim))
axScatter.set_ylim((-lim, lim))

bins = np.arange(-lim, lim + binwidth, binwidth)
axHistx.hist(x, bins=bins)
axHisty.hist(y, bins=bins, orientation='horizontal')

#axHistx.set_xlim(axScatter.get_xlim())
#axHisty.set_ylim(axScatter.get_ylim())

plt.show()

# %%
for i in range(len(x)):
    print ("{0}\t{1}".format(x[i], y[i]))
# Out:
# -0.437445568809	0.011552878151
# -2.84681977402	2.30871979209
# -1.43731150982	0.296929204787
# 1.20132345476	-0.429075534852
# -0.454382479396	0.00936006606534
# -0.888322670576	-0.311616620756
# 1.75367528065	-0.512379146133
# -0.314715502733	0.103486258501
# -1.11352114335	-0.0631702635636
# -0.24085239253	0.00835727561552
# -0.947170113005	0.086904003837
# -1.94369605378	1.12835126806
# -1.37574380747	0.261819942767
# 0.150825942529	0.00488607659517
# 0.373315267107	-0.0333905664528
# 0.97017675555	0.0204264153033
# -0.312279462788	0.00424114924033
# -1.45040065943	-0.147887998964
# -0.870075299065	0.0321230398839
# -0.643146000007	-0.260359278142
# -0.0325691517488	-0.141782126109
# 1.90330845653	-0.721900744894
# 0.17377898107	-0.0458855611656
# 1.39420248414	-0.0894142932746
# -0.963931390477	0.0929474654158
# 0.238234415193	0.00818263489995
# -1.35565396336	0.249141770292
# 0.0738974929029	-0.00206054135602
# -0.600428651422	0.124414631866
# 0.322030632678	-0.00332262594893
# ...

# %%
print ("\n").join(["{0}\t{1}".format(x[i], y[i]) for i in range(len(x))])
# Out:
# -0.437445568809	0.011552878151
# -2.84681977402	2.30871979209
# -1.43731150982	0.296929204787
# 1.20132345476	-0.429075534852
# -0.454382479396	0.00936006606534
# -0.888322670576	-0.311616620756
# 1.75367528065	-0.512379146133
# -0.314715502733	0.103486258501
# -1.11352114335	-0.0631702635636
# -0.24085239253	0.00835727561552
# -0.947170113005	0.086904003837
# -1.94369605378	1.12835126806
# -1.37574380747	0.261819942767
# 0.150825942529	0.00488607659517
# 0.373315267107	-0.0333905664528
# 0.97017675555	0.0204264153033
# -0.312279462788	0.00424114924033
# -1.45040065943	-0.147887998964
# -0.870075299065	0.0321230398839
# -0.643146000007	-0.260359278142
# -0.0325691517488	-0.141782126109
# 1.90330845653	-0.721900744894
# 0.17377898107	-0.0458855611656
# 1.39420248414	-0.0894142932746
# -0.963931390477	0.0929474654158
# 0.238234415193	0.00818263489995
# -1.35565396336	0.249141770292
# 0.0738974929029	-0.00206054135602
# -0.600428651422	0.124414631866
# 0.322030632678	-0.00332262594893
# ...

# %%
f = open('test.txt', 'w') # 書き込みモードで開く
f.write(("\n").join(["{0}\t{1}".format(x[i], y[i]) for i in range(len(x))]))
f.close() # ファイルを閉じる

# %%
with open('test.txt', 'r') as f:
    print(f.read())
# Out:
# -0.437445568809	0.011552878151
# -2.84681977402	2.30871979209
# -1.43731150982	0.296929204787
# 1.20132345476	-0.429075534852
# -0.454382479396	0.00936006606534
# -0.888322670576	-0.311616620756
# 1.75367528065	-0.512379146133
# -0.314715502733	0.103486258501
# -1.11352114335	-0.0631702635636
# -0.24085239253	0.00835727561552
# -0.947170113005	0.086904003837
# -1.94369605378	1.12835126806
# -1.37574380747	0.261819942767
# 0.150825942529	0.00488607659517
# 0.373315267107	-0.0333905664528
# 0.97017675555	0.0204264153033
# -0.312279462788	0.00424114924033
# -1.45040065943	-0.147887998964
# -0.870075299065	0.0321230398839
# -0.643146000007	-0.260359278142
# -0.0325691517488	-0.141782126109
# 1.90330845653	-0.721900744894
# 0.17377898107	-0.0458855611656
# 1.39420248414	-0.0894142932746
# -0.963931390477	0.0929474654158
# 0.238234415193	0.00818263489995
# -1.35565396336	0.249141770292
# 0.0738974929029	-0.00206054135602
# -0.600428651422	0.124414631866
# 0.322030632678	-0.00332262594893
# ...

# %%
import pandas as pd
data = pd.read_csv( 'test.txt', delimiter='\t', header=None)

# %%
data
# Out:
#             0         1
# 0   -0.437446  0.011553
# 1   -2.846820  2.308720
# 2   -1.437312  0.296929
# 3    1.201323 -0.429076
# 4   -0.454382  0.009360
# 5   -0.888323 -0.311617
# 6    1.753675 -0.512379
# 7   -0.314716  0.103486
# 8   -1.113521 -0.063170
# 9   -0.240852  0.008357
# 10  -0.947170  0.086904
# 11  -1.943696  1.128351
# 12  -1.375744  0.261820
# 13   0.150826  0.004886
# 14   0.373315 -0.033391
# 15   0.970177  0.020426
# 16  -0.312279  0.004241
# 17  -1.450401 -0.147888
# 18  -0.870075  0.032123
# 19  -0.643146 -0.260359
# 20  -0.032569 -0.141782
# 21   1.903308 -0.721901
# 22   0.173779 -0.045886
# 23   1.394202 -0.089414
# 24  -0.963931  0.092947
# 25   0.238234  0.008183
# 26  -1.355654  0.249142
# 27   0.073897 -0.002061
# 28  -0.600429  0.124415
# 29   0.322031 -0.003323
# ..        ...       ...
# 470 -0.418676  1.394257
# 471 -0.028905 -0.376692
# 472  1.025825 -1.611320
# 473 -1.698575  0.372295
# 474 -0.343744  0.065574
# 475  0.997782 -0.123398
# ...

# %%
import pandas as pd
data =pd.read_csv( 'test.txt', delimiter='\t', header=None, names=('x', 'y'))

# %%
data
# Out:
#             x         y
# 0   -0.437446  0.011553
# 1   -2.846820  2.308720
# 2   -1.437312  0.296929
# 3    1.201323 -0.429076
# 4   -0.454382  0.009360
# 5   -0.888323 -0.311617
# 6    1.753675 -0.512379
# 7   -0.314716  0.103486
# 8   -1.113521 -0.063170
# 9   -0.240852  0.008357
# 10  -0.947170  0.086904
# 11  -1.943696  1.128351
# 12  -1.375744  0.261820
# 13   0.150826  0.004886
# 14   0.373315 -0.033391
# 15   0.970177  0.020426
# 16  -0.312279  0.004241
# 17  -1.450401 -0.147888
# 18  -0.870075  0.032123
# 19  -0.643146 -0.260359
# 20  -0.032569 -0.141782
# 21   1.903308 -0.721901
# 22   0.173779 -0.045886
# 23   1.394202 -0.089414
# 24  -0.963931  0.092947
# 25   0.238234  0.008183
# 26  -1.355654  0.249142
# 27   0.073897 -0.002061
# 28  -0.600429  0.124415
# 29   0.322031 -0.003323
# ..        ...       ...
# 470 -0.418676  1.394257
# 471 -0.028905 -0.376692
# 472  1.025825 -1.611320
# 473 -1.698575  0.372295
# 474 -0.343744  0.065574
# 475  0.997782 -0.123398
# ...

# %%
data['x']
# Out:
# 0     -0.437446
# 1     -2.846820
# 2     -1.437312
# 3      1.201323
# 4     -0.454382
# 5     -0.888323
# 6      1.753675
# 7     -0.314716
# 8     -1.113521
# 9     -0.240852
# 10    -0.947170
# 11    -1.943696
# 12    -1.375744
# 13     0.150826
# 14     0.373315
# 15     0.970177
# 16    -0.312279
# 17    -1.450401
# 18    -0.870075
# 19    -0.643146
# 20    -0.032569
# 21     1.903308
# 22     0.173779
# 23     1.394202
# 24    -0.963931
# 25     0.238234
# 26    -1.355654
# 27     0.073897
# 28    -0.600429
# 29     0.322031
#          ...
# 470   -0.418676
# 471   -0.028905
# 472    1.025825
# 473   -1.698575
# 474   -0.343744
# 475    0.997782
# 476   -0.234133
# 477    1.213164
# 478    0.765504
# 479   -1.063502
# 480    1.178608
# 481    0.882149
# 482   -1.968821
# 483    0.219475
# 484    0.214813
# 485   -1.814348
# 486   -1.216640
# 487    0.186038
# 488    1.951857
# 489   -0.535693
# 490   -0.433166
# 491    1.956544
# 492    0.784004
# 493   -1.152792
# ...

# %%
data['y']
# Out:
# 0      0.011553
# 1      2.308720
# 2      0.296929
# 3     -0.429076
# 4      0.009360
# 5     -0.311617
# 6     -0.512379
# 7      0.103486
# 8     -0.063170
# 9      0.008357
# 10     0.086904
# 11     1.128351
# 12     0.261820
# 13     0.004886
# 14    -0.033391
# 15     0.020426
# 16     0.004241
# 17    -0.147888
# 18     0.032123
# 19    -0.260359
# 20    -0.141782
# 21    -0.721901
# 22    -0.045886
# 23    -0.089414
# 24     0.092947
# 25     0.008183
# 26     0.249142
# 27    -0.002061
# 28     0.124415
# 29    -0.003323
#          ...
# 470    1.394257
# 471   -0.376692
# 472   -1.611320
# 473    0.372295
# 474    0.065574
# 475   -0.123398
# 476    0.000953
# 477   -0.091475
# 478   -0.084274
# 479   -0.078130
# 480   -0.117441
# 481    0.155505
# 482    0.764046
# 483   -0.009747
# 484   -0.015742
# 485    0.372563
# 486    0.169511
# 487    0.002137
# 488   -0.783165
# 489    0.196107
# 490    0.008066
# 491   -0.748011
# 492   -0.047464
# 493    0.153154
# ...

# %%
data.size
# Out:
# 1000

# %%
data.describe()
# Out:
#                 x           y
# count  500.000000  500.000000
# mean    -0.058768    0.014064
# std      1.040060    0.555261
# min     -2.961702   -3.627664
# 25%     -0.795223   -0.086173
# 50%      0.019717    0.001010
# 75%      0.632164    0.113298
# max      2.920193    2.597983

# %%
y = [data['x'][n] * 10 for n in range(data['x'].size)] * 10
x = [data['y'][n] * 10 for n in range(data['y'].size)] * 10

# %%
nullfmt = NullFormatter()         # no labels

# definitions for the axes
left, width = 0.1, 0.65
bottom, height = 0.1, 0.65
bottom_h = left_h = left + width + 0.02

rect_scatter = [left, bottom, width, height]
rect_histx = [left, bottom_h, width, 0.2]
rect_histy = [left_h, bottom, 0.2, height]

# start with a rectangular Figure
plt.figure(1, figsize=(8, 8))

axScatter = plt.axes(rect_scatter)
axHistx = plt.axes(rect_histx)
axHisty = plt.axes(rect_histy)

# no labels
axHistx.xaxis.set_major_formatter(nullfmt)
axHisty.yaxis.set_major_formatter(nullfmt)

# the scatter plot:
axScatter.scatter(x, y)

# now determine nice limits by hand:
binwidth = 0.25
xymax = np.max([np.max(np.fabs(x)), np.max(np.fabs(y))])
lim = (int(xymax/binwidth) + 1) * binwidth

axScatter.set_xlim((-lim, lim))
axScatter.set_ylim((-lim, lim))

bins = np.arange(-lim, lim + binwidth, binwidth)
axHistx.hist(x, bins=bins)
axHisty.hist(y, bins=bins, orientation='horizontal')

#axHistx.set_xlim(axScatter.get_xlim())
#axHisty.set_ylim(axScatter.get_ylim())

plt.show()
