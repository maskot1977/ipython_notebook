# %% [markdown]
# # アイスクリーム統計学 + Python (第１章〜第３章)
# [アイスクリーム統計学にようこそ！](http://kogolab.chillout.jp/elearn/icecream/index.html)
# のページを読み進めながら、以下の課題を Python を使って解いてください。

# %% [markdown]
# ## 1.　[散布図と相関](http://kogolab.chillout.jp/elearn/icecream/chap1/sec0.html)
# 本文を読んで概念を学んでください。

# %% [markdown]
# ### 1.1　[最高気温と客数の関係](http://kogolab.chillout.jp/elearn/icecream/chap1/sec1.html)
# 表　[別のチェーン店の８月の客数データ（14日分）](https://raw.githubusercontent.com/maskot1977/ipython_notebook/master/toydata/ice_cream.txt)
# を用いて、以下のコードを実行してください。

# %%
# URL によるリソースへのアクセスを提供するライブラリをインポートする。
import urllib # Python 2 の場合
# import urllib.request # Python 3 の場合

# %%
# ウェブ上のリソースを指定する
url = 'https://raw.githubusercontent.com/maskot1977/ipython_notebook/master/toydata/ice_cream.txt'

# %%
# 指定したURLからリソースをダウンロードし、名前をつける。
urllib.urlretrieve(url, 'ice_cream.txt') # Python 2 の場合
# urllib.request.urlretrieve(url, 'ice_cream.txt') # Python 3 の場合
# Out:
# ('ice_cream.txt', <httplib.HTTPMessage instance at 0x10411be18>)

# %%
# ダウンロードしたデータから、列ごとに数字を読み込んでリストに格納する。
col1 = [] # ０列目の数字を格納する予定のリスト
col2 = [] # １列目の数字を格納する予定のリスト
col3 = [] # ２列目の数字を格納する予定のリスト
for i, line in enumerate(open('ice_cream.txt')): # ファイルを開いて一行一行読み込む
    if i == 0: # ０番目の行の場合
        continue # 次の行に行く
    c = line.split() # 行を空白文字で分割したものをcというリストに入れる
    col1.append(int(c[0])) # ０列目の単語を整数に変換してcol1に入れる
    col2.append(int(c[1])) # １列目の単語を整数に変換してcol2に入れる
    col3.append(int(c[2])) # ２列目の単語を整数に変換してcol3に入れる

# %% [markdown]
# ### 1.2　[散布図を描く](http://kogolab.chillout.jp/elearn/icecream/chap1/sec2.html)
# 以下のコードを実行してください。

# %%
# 図やグラフを図示するためのライブラリをインポートする。
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 折れ線グラフを描く。
plt.plot(col1, col2, label="Temperature")
plt.plot(col1, col3, label="Customers")
plt.legend(loc='best',fancybox=True, shadow=True)
plt.title("Numbers of customers in August")
plt.xlabel("Day")
plt.show()

# %%
# 折れ線グラフを２つのサブプロットで描く。
plt.figure(figsize=(8, 4))

plt.subplot(2, 1, 1)
plt.plot(col1, col2)
plt.title('Numbers of customers in August')
plt.xticks([])
plt.ylabel('Temperature')

plt.subplot(2, 1, 2)
plt.plot(col1, col3)
plt.xticks(rotation=90)
plt.xlabel('Day')
plt.ylabel('Customers')

plt.show()

# %%
#散布図を描く。
plt.scatter(col2, col3, alpha=0.5)
plt.title("Numbers of customers in August")
plt.xlabel("Temperature")
plt.ylabel("Customers")
for day, x, y in zip(col1, col2, col3):
    plt.text(x, y, day, alpha=0.8, size=12)
plt.show()

# %% [markdown]
# ### 1.3　[散布図のパターン](http://kogolab.chillout.jp/elearn/icecream/chap1/sec3.html)
#
# 本文を読んで概念を学んでください。

# %% [markdown]
# ### 1.4　[（応用編）駅からの距離と客数の関係](http://kogolab.chillout.jp/elearn/icecream/chap1/sec4.html)

# %% [markdown]
# __課題1.4__：　[店舗別８月の平均客数データ（12店舗）](https://raw.githubusercontent.com/maskot1977/ipython_notebook/master/toydata/shop_distance.txt) をダウンロードし、散布図を描いてください。その上で、駅から250メートルの店の客数を予測してください。

# %%
# ウェブ上のリソースを指定する
url = 'https://raw.githubusercontent.com/maskot1977/ipython_notebook/master/toydata/shop_distance.txt'
# ダウンロードしたデータから、列ごとに数字を読み込んでリストに格納する。
# 指定したURLからリソースをダウンロードし、名前をつける。
urllib.urlretrieve(url, 'shop_distance.txt') # Python 2 の場合
# urllib.request.urlretrieve(url, 'shop_distance.txt') # Python 3 の場合
# Out:
# ('shop_distance.txt', <httplib.HTTPMessage instance at 0x10f2d80e0>)

# %%
# ダウンロードしたデータから、列ごとに数字を読み込んでリストに格納する。
col1 = []
col2 = []
col3 = []
for i, line in enumerate(open('shop_distance.txt')):
    if i == 0:
        continue
    a = line.split()
    col1.append(int(a[0]))
    col2.append(int(a[1]))
    col3.append(int(a[2]))

# %%
#散布図を描く。
plt.scatter(col2, col3, alpha=0.5)
plt.title("Shop distance and customers")
plt.xlabel("Distance")
plt.ylabel("Customers")
for day, x, y in zip(col1, col2, col3):
    plt.text(x, y, day, alpha=0.8, size=12)
plt.show()

# %% [markdown]
# ### 1.5　[通過テスト](http://kogolab.chillout.jp/elearn/icecream/chap1/sec5.html)

# %% [markdown]
# __課題1.5__：　[入学試験の点数と学業成績](https://raw.githubusercontent.com/maskot1977/ipython_notebook/master/toydata/entrance_exam.txt) をダウンロードし、以下の問いに答えてください。
# * 散布図を描いてください。
# * 散布図からどのようなことが読みとれるかを文章で書いてください。
#
# __ヒント__：文字列を整数に変換する関数は int ですが、少数点数に変換する関数は float です。

# %%
# ウェブ上のリソースを指定する
url = 'https://raw.githubusercontent.com/maskot1977/ipython_notebook/master/toydata/entrance_exam.txt'
# ダウンロードしたデータから、列ごとに数字を読み込んでリストに格納する。
# 指定したURLからリソースをダウンロードし、名前をつける。
urllib.urlretrieve(url, 'entrance_exam.txt') # Python 2 の場合
# urllib.request.urlretrieve(url, 'entrance_exam.txt') # Python 3 の場合
# Out:
# ('entrance_exam.txt', <httplib.HTTPMessage instance at 0x10f29f710>)

# %%
# ダウンロードしたデータから、列ごとに数字を読み込んでリストに格納する。
col1 = []
col2 = []
col3 = []
for i, line in enumerate(open('entrance_exam.txt')):
    if i == 0:
        continue
    a = line.split()
    col1.append(int(a[0]))
    col2.append(int(a[1]))
    col3.append(float(a[2]))

# %%
#散布図を描く。
plt.scatter(col2, col3, alpha=0.5)
plt.title("Entrance exam and university score")
plt.xlabel("Entrance exam")
plt.ylabel("University score")
for day, x, y in zip(col1, col2, col3):
    plt.text(x, y, day, alpha=0.8, size=12)
plt.show()

# %% [markdown]
# ## 2.　[相関係数](http://kogolab.chillout.jp/elearn/icecream/chap2/sec0.html)
# 本文を読んで概念を学んでください。

# %% [markdown]
# ### 2.1　[相関の強さ](http://kogolab.chillout.jp/elearn/icecream/chap2/sec1.html)

# %% [markdown]
# __課題2.1__：　[店舗Aと店舗Bの８月の客数データ](https://raw.githubusercontent.com/maskot1977/ipython_notebook/master/toydata/shopAandB.txt)をダウンロードし、下記の例のように散布図を描いてください。
#
# __ヒント__：今度のデータは全部で４列。４列目は店舗AかBかを表す列なので、これを利用して場合分けをする必要があります。Aの０列目、１列目、２列目をそれぞれ col1a, col2a, col3a、Bの０列目、１列目、２列目をそれぞれ col2a, col2b, col2c という名のリストに格納してください。

# %%
# ダウンロードしたデータから、列ごとに数字を読み込んでリストに格納する。
col1a = []
col2a = []
col3a = []
col1b = []
col2b = []
col3b = []
for i, line in enumerate(open('shopAandB.txt')):
    if i == 0:
        continue
    a = line.split()
    if a[3] == "A":
        col1a.append(int(a[0]))
        col2a.append(int(a[1]))
        col3a.append(float(a[2]))
    elif a[3] == "B":
        col1b.append(int(a[0]))
        col2b.append(int(a[1]))
        col3b.append(float(a[2]))

# %%
#２つのサブプロットを使って散布図を描く。
plt.figure(figsize=(8, 4))

plt.subplot(1, 2, 1)
plt.scatter(col2a, col3a, alpha=0.5)
plt.title("ShopA")
plt.xlabel("Temperature")
plt.ylabel("Customers")
plt.xlim([25, 35])
plt.ylim([250, 500])
for day, x, y in zip(col1a, col2a, col3a):
    plt.text(x, y, day, alpha=0.8, size=12)

plt.subplot(1, 2, 2)
plt.scatter(col2b, col3b, alpha=0.5)
plt.title("ShopB")
plt.xlabel("Tempareture")
plt.xlim([25, 35])
plt.ylim([250, 500])
for day, x, y in zip(col1b, col2b, col3b):
    plt.text(x, y, day, alpha=0.8, size=12)

plt.show()

# %% [markdown]
# ### 2.2　[相関係数](http://kogolab.chillout.jp/elearn/icecream/chap2/sec2.html)

# %% [markdown]
# __課題2.2__：本文を読み、相関係数の計算方法を学んでください。その上で、[店舗Aと店舗Bの８月の客数データ](https://raw.githubusercontent.com/maskot1977/ipython_notebook/master/toydata/shopAandB.txt)のデータを用い、店Aにおける最高気温と来客数の間の相関係数、店Bにおける最高気温と来客数の間の相関係数をそれぞれ求めてください。

# %%
# 平均値を求める関数
def average(list):
    sum = 0.0
    n = 0.0
    for x in list:
        sum += x
        n += 1.0
    return sum / n

# %%
# 分散を求める関数
def variance(list):
    ave = average(list)
    sum = 0.0
    n = 0.0
    for x in list:
        sum += (x - ave) ** 2.0
        n += 1.0
    return sum / n

# %%
# 標準偏差を求める関数
import math
def standard_deviation(list):
    return math.sqrt(variance(list))

# %%
# 共分散（偏差積の平均）を求める関数
def covariance(list1, list2): 
    ave1 = average(list1)
    ave2 = average(list2)
    sum = 0.0
    n = 0.0
    for d1, d2 in zip(list1, list2):
        sum += (d1 - ave1) * (d2 - ave2)
        n += 1.0
    return sum / n

# %%
# 相関係数を求める関数
def correlation(list1, list2):
    return covariance(list1, list2) / (standard_deviation(list1) * standard_deviation(list2))

# %%
# 店Aにおける最高気温と来客数の間の相関係数
correlation(col2a, col3a)
# Out:
# 0.7600264583679087

# %%
# 店Bにおける最高気温と来客数の間の相関係数
correlation(col2b, col3b)
# Out:
# 0.9635381388496952

# %% [markdown]
# ### 2.3　[相関係数の意味(1)](http://kogolab.chillout.jp/elearn/icecream/chap2/sec3.html)
# 本文を読んで概念を学んでください。

# %% [markdown]
# ### 2.4　[相関係数の意味(2)](http://kogolab.chillout.jp/elearn/icecream/chap2/sec4.html)
# 本文を読んで概念を学んでください。

# %% [markdown]
# ### 2.5　[（応用編）相関の強さ](http://kogolab.chillout.jp/elearn/icecream/chap2/sec5.html)

# %% [markdown]
# __課題2.5__：　[店舗別８月の平均客数データ（12店舗）](https://raw.githubusercontent.com/maskot1977/ipython_notebook/master/toydata/shop_distance.txt)を用い、駅からの距離(m)と平均客数の間の相関係数を求めてください。

# %%
# ダウンロードしたデータから、列ごとに数字を読み込んでリストに格納する。
col1 = []
col2 = []
col3 = []
for i, line in enumerate(open('shop_distance.txt')):
    if i == 0:
        continue
    a = line.split()
    col1.append(int(a[0]))
    col2.append(int(a[1]))
    col3.append(int(a[2]))

# %%
correlation(col2, col3)
# Out:
# -0.9795221182977909

# %% [markdown]
# ### 2.6　[通過テスト](http://kogolab.chillout.jp/elearn/icecream/chap2/sec6.html)

# %% [markdown]
# __課題2.6__：　[入学試験の点数と学業成績](https://raw.githubusercontent.com/maskot1977/ipython_notebook/master/toydata/entrance_exam.txt) をダウンロードし、以下の問いに答えてください。
# * 入学試験の点数と学業成績の間の相関係数を求めてください。
# * 相関係数からどのようなことが言えるかを文章で書いてください。

# %%
# ダウンロードしたデータから、列ごとに数字を読み込んでリストに格納する。
col1 = []
col2 = []
col3 = []
for i, line in enumerate(open('entrance_exam.txt')):
    if i == 0:
        continue
    a = line.split()
    col1.append(int(a[0]))
    col2.append(int(a[1]))
    col3.append(float(a[2]))

# %%
correlation(col2, col3)
# Out:
# 0.7617976726140626

# %%
# 入学試験の点数と学業成績の間には強い正の相関がある。つまり、入学試験の点数が高いほど、学業成績が良い傾向がある。

# %% [markdown]
# ## 3.　[無相関検定](http://kogolab.chillout.jp/elearn/icecream/chap3/sec0.html)
# 本文を読んで概念を学んでください。

# %% [markdown]
# ### 3.1　[母集団と標本集団](http://kogolab.chillout.jp/elearn/icecream/chap3/sec1.html)
# 本文を読んで概念を学んでください。

# %% [markdown]
# ### 3.2　[標本集団の相関係数](http://kogolab.chillout.jp/elearn/icecream/chap3/sec2.html)

# %% [markdown]
# __課題3.2__：[標本のデータ](https://raw.githubusercontent.com/maskot1977/ipython_notebook/master/toydata/specimen.txt)を用いて、以下の問いに答えてください。
# * 散布図を描いてください。
# * 相関係数を計算してください。

# %%
# ウェブ上のリソースを指定する
url = 'https://raw.githubusercontent.com/maskot1977/ipython_notebook/master/toydata/specimen.txt'
# ダウンロードしたデータから、列ごとに数字を読み込んでリストに格納する。
# 指定したURLからリソースをダウンロードし、名前をつける。
urllib.urlretrieve(url, 'specimen.txt') # Python 2 の場合
# urllib.request.urlretrieve(url, 'specimen.txt') # Python 3 の場合
# Out:
# ('specimen.txt', <httplib.HTTPMessage instance at 0x10f635488>)

# %%
# ダウンロードしたデータから、列ごとに数字を読み込んでリストに格納する。
col1 = []
col2 = []
col3 = []
for i, line in enumerate(open('specimen.txt')):
    if i == 0:
        continue
    a = line.split()
    col1.append(int(a[0]))
    col2.append(int(a[1]))
    col3.append(int(a[2]))

# %%
#散布図を描く。
plt.scatter(col2, col3, alpha=0.5)
plt.title("Age and frequency")
plt.xlabel("Age")
plt.ylabel("Frequency")
for day, x, y in zip(col1, col2, col3):
    plt.text(x, y, day, alpha=0.8, size=12)
plt.show()

# %%
correlation(col2, col3)
# Out:
# 0.26652273871533966

# %% [markdown]
# ### 3.3　[無相関検定](http://kogolab.chillout.jp/elearn/icecream/chap3/sec3.html)
# 本文を読んで概念を学んでください。

# %% [markdown]
# ### 3.4　[標本数による限界値](http://kogolab.chillout.jp/elearn/icecream/chap3/sec4.html)
# 本文を読んで概念を学んでください。

# %% [markdown]
# ### 3.5　[（応用編）無相関検定](http://kogolab.chillout.jp/elearn/icecream/chap3/sec5.html)
# 本文を読んで概念を学んでください。

# %% [markdown]
# ### 3.6　[通過テスト](http://kogolab.chillout.jp/elearn/icecream/chap3/sec6.html)

# %% [markdown]
# __課題3.6__：　[入学試験の点数と学業成績](https://raw.githubusercontent.com/maskot1977/ipython_notebook/master/toydata/entrance_exam.txt) をダウンロードし、以下の問いに答えてください。
# * このデータが、この大学の大学生全体からの無作為抽出された標本としたとき、相関係数からどのようなことが言えるかを、統計学のことばで説明してください。ここで、標本数19の時の限界値は、0.456（5%有意水準）、および0.575（1%有意水準）であるとします。
# * その内容をわかりやすいコトバで言い換えてください。

# %%
# 相関係数は 0.76 なので、5%有意水準でも1%有意水準でも
# 標本数19の相関係数は0.76である。
# 有意水準5%における限界値は0.456なので、帰無仮説「母集団の相関係数はゼロ」は棄却できる。
# つまり、標本数19での相関係数0.76は、母集団の相関係数がゼロと仮定したときに、なかなか起こりえない。
# したがって、0.76という相関係数は有意な値といえる。
# また、有意水準1%に厳しくしても、その限界値は0.575であり、この場合もこの相関係数は有意といえる。

# %% [markdown]
# __今日の課題提出__：計算結果を.ipynb ファイル（または.jsonファイル）として保存し、指定したアドレスまでメールしてください。メールタイトルは「生命統計学課題」とし、メール本文に学籍番号と氏名を明記のこと。また、感想も書いてくれると喜びます。今後の講義の改善につながるかも知れません。
